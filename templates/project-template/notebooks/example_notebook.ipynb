# %% [markdown]
# # Example Notebook
#
# This is a template notebook for exploratory data analysis and experiments.

# %%
import numpy as np
import matplotlib.pyplot as plt

# TODO: Import from smon-toolbox
# from smon_toolbox.linear import cholesky_factorization

# %%
# Set random seed for reproducibility
np.random.seed(42)

# %% [markdown]
# ## Your analysis here
